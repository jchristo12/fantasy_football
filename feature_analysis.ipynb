# %% [markdown]
# # Feature data only

# %%
import pandas as pd
import numpy as np
import math
import os
import seaborn as sb

# %% [markdown]
# ## Read in the data

# %%
player = pd.read_csv('https://raw.githubusercontent.com/jchristo12/fantasy_football/master/data/predictor/player_offense.csv')

# %%
#rename columns
player.rename(columns={'seas.1': 'exp'}, inplace=True)

# %%
player.columns
# Out:
# Index(['pk', 'gid', 'seas', 'wk', 'player', 'fname', 'lname', 'full_name',
#        'team', 'pos1', 'nflid', 'pa', 'pc', 'py', 'ints', 'tdp', 'ra', 'sra',
#        'ry', 'tdr', 'fuml', 'trg', 'rec', 'recy', 'tdrec', 'ret', 'rety',
#        'tdret', 'exp', 'height', 'weight', 'dob', 'dv', 'forty', 'bench',
#        'vertical', 'broad', 'shuttle', 'cone', 'arm', 'hand'],
#       dtype='object')

# %%
#convert column types to appropriate data types
player = player.astype({'seas': 'category',
          'wk': 'category',
          'team': 'category',
          'pos1': 'category',
          'dv': 'category',
          'exp': 'category'})

# %% [markdown]
# ## Cumulative Stats

# %% [markdown]
# Need to lag the information by one week to see if we can predict the next week's fantasy points.<br>
# The game information can stay at the current week as long as we can know it before the week.

# %%
#sort the stats
player_sorted = player.sort_values(by=['player', 'gid'], ascending=True)

# %%
player_sorted.head()
# Out:
#                  pk   gid  seas wk   player  fname     lname       full_name  \
# 74708  3999&AA-0025  3999  2015  1  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 74935  4010&AA-0025  4010  2015  2  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 75490  4036&AA-0025  4036  2015  3  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 75814  4052&AA-0025  4052  2015  4  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 76021  4062&AA-0025  4062  2015  5  AA-0025  Ameer  Abdullah  Ameer Abdullah
#
#       team pos1  ...          dob       dv  forty  bench  vertical  broad  \
# 74708  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 74935  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 75490  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 75814  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 76021  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
#
#        shuttle  cone   arm   hand
# 74708     3.95  6.79  30.0  8.625
# 74935     3.95  6.79  30.0  8.625
# 75490     3.95  6.79  30.0  8.625
# 75814     3.95  6.79  30.0  8.625
# 76021     3.95  6.79  30.0  8.625
#
# [5 rows x 41 columns]

# %%
#unique player list
unique_players = player_sorted['player'].unique()

# %%
player_sorted.loc[player_sorted['player'] == 'AA-0025', 'seas'].unique()
# Out:
# [2015, 2016, 2017, 2018]
# Categories (4, int64): [2015, 2016, 2017, 2018]

# %% [markdown]
# #### Career stats

# %%
#initialize a list to hold all cumulative stats
cusum_stats = []

# %%
#loop through all unique players and calculate cumulative stats
for i in unique_players:
    x = player_sorted.loc[player_sorted['player'] == i, 'pa':'tdret'].shift(1).cumsum()
    cusum_stats.append(x)

# %%
#combine all of the items in the list into 1 dataframe
cusum_df = pd.concat(cusum_stats, axis=0)

# %%
#check to see if length matches the original dataframe
print(cusum_df.shape[0])
print(player.shape[0])
# Out:
# 94759
# 94759

# %% [markdown]
# Proof that this method is calculating correctly (lengths match)

# %%
#rename columns to add a cusum prefix
cusum_df = cusum_df.add_prefix('cusum_')

# %%
#add the cusum data to the sorted data frame
player_sorted_cusum = pd.concat([player_sorted, cusum_df], axis=1)

# %% [markdown]
# #### 4-game rolling

# %% [markdown]
# 4-game rolling sum for each season<br>
# Lagged by 1 week

# %%
player_sorted.head()
# Out:
#                  pk   gid  seas wk   player  fname     lname       full_name  \
# 74708  3999&AA-0025  3999  2015  1  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 74935  4010&AA-0025  4010  2015  2  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 75490  4036&AA-0025  4036  2015  3  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 75814  4052&AA-0025  4052  2015  4  AA-0025  Ameer  Abdullah  Ameer Abdullah
# 76021  4062&AA-0025  4062  2015  5  AA-0025  Ameer  Abdullah  Ameer Abdullah
#
#       team pos1  ...          dob       dv  forty  bench  vertical  broad  \
# 74708  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 74935  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 75490  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 75814  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
# 76021  DET   RB  ...    6/13/1993  Big Ten    4.5     24      42.5    130
#
#        shuttle  cone   arm   hand
# 74708     3.95  6.79  30.0  8.625
# 74935     3.95  6.79  30.0  8.625
# 75490     3.95  6.79  30.0  8.625
# 75814     3.95  6.79  30.0  8.625
# 76021     3.95  6.79  30.0  8.625
#
# [5 rows x 41 columns]

# %%
#initialize a list to hold each players rolling sum
recent_stats = []

# %%
#loop thru each unique player calculating rolling sum
for i in unique_players:
    interim_df = player_sorted.loc[player_sorted['player'] == i, :]
    unique_seas = interim_df['seas'].unique()
    for s in unique_seas:
        s_stat = interim_df.loc[interim_df['seas'] == s, 'pa':'tdret'].shift(1).rolling(window=4, min_periods=1).sum()
        recent_stats.append(s_stat)

# %%
#combine the items in the recent stats list
recent_df = pd.concat(recent_stats, axis=0)

# %%
#make sure lengths match the original
print(recent_df.shape[0])
print(player.shape[0])
# Out:
# 94759
# 94759

# %%
#rename columns to add a recent prefix
recent_df = recent_df.add_prefix('recent_')

# %%
#add the recent stats columns to the sorted data frame
player_rolling_sort = pd.concat([player_sorted_cusum, recent_df], axis=1)

# %% [markdown]
# ## Add other features

# %%
player_rolling_sort.columns
# Out:
# Index(['pk', 'gid', 'seas', 'wk', 'player', 'fname', 'lname', 'full_name',
#        'team', 'pos1', 'nflid', 'pa', 'pc', 'py', 'ints', 'tdp', 'ra', 'sra',
#        'ry', 'tdr', 'fuml', 'trg', 'rec', 'recy', 'tdrec', 'ret', 'rety',
#        'tdret', 'exp', 'height', 'weight', 'dob', 'dv', 'forty', 'bench',
#        'vertical', 'broad', 'shuttle', 'cone', 'arm', 'hand', 'cusum_pa',
#        'cusum_pc', 'cusum_py', 'cusum_ints', 'cusum_tdp', 'cusum_ra',
#        'cusum_sra', 'cusum_ry', 'cusum_tdr', 'cusum_fuml', 'cusum_trg',
#        'cusum_rec', 'cusum_recy', 'cusum_tdrec', 'cusum_ret', 'cusum_rety',
#        'cusum_tdret', 'recent_pa', 'recent_pc', 'recent_py', 'recent_ints',
#        'recent_tdp', 'recent_ra', 'recent_sra', 'recent_ry', 'recent_tdr',
#        'recent_fuml', 'recent_trg', 'recent_rec', 'recent_recy',
#        'recent_tdrec', 'recent_ret', 'recent_rety', 'recent_tdret'],
#       dtype='object')

# %% [markdown]
# ### Passing summaries

# %% [markdown]
# #### Career stats

# %%
#Passing completion
player_rolling_sort['career_comp_pct'] = player_rolling_sort['cusum_pc'] / player_rolling_sort['cusum_pa']

# %%
#touchdown to interception ratio
player_rolling_sort['career_td_to_int'] = player_rolling_sort['cusum_tdp'] / player_rolling_sort['cusum_ints']

# %%
#Passing yards per completion
player_rolling_sort['career_yds_per_comp'] = player_rolling_sort['cusum_py'] / player_rolling_sort['cusum_pc']

# %% [markdown]
# #### Recent stats

# %%
#Passing completion
player_rolling_sort['recent_comp_pct'] = player_rolling_sort['recent_pc'] / player_rolling_sort['recent_pa']

# %%
#touchdown to interception ratio
player_rolling_sort['recent_td_to_int'] = player_rolling_sort['recent_tdp'] / player_rolling_sort['recent_ints']

# %%
#Passing yards per completion
player_rolling_sort['recent_yds_per_comp'] = player_rolling_sort['recent_py'] / player_rolling_sort['recent_pc']

# %% [markdown]
# ### Running summaries

# %% [markdown]
# #### Career stats

# %%
#Yards per rush
player_rolling_sort['career_ryds_per_carry'] = player_rolling_sort['cusum_ry'] / player_rolling_sort['cusum_ra']

# %%
#Carries to touchdown ratio
player_rolling_sort['career_carry_to_td'] = player_rolling_sort['cusum_ra'] / player_rolling_sort['cusum_tdr']

# %%
#Carries to fumbles lost ratio
player_rolling_sort['career_carry_to_fuml'] = player_rolling_sort['cusum_ra'] / player_rolling_sort['cusum_fuml']

# %% [markdown]
# #### Recent stats

# %%
#Yards per rush
player_rolling_sort['recent_ryds_per_carry'] = player_rolling_sort['recent_ry'] / player_rolling_sort['recent_ra']

# %%
#Carries to touchdown ratio
player_rolling_sort['recent_carry_to_td'] = player_rolling_sort['recent_ra'] / player_rolling_sort['recent_tdr']

# %%
#Carries to fumbles lost ratio
player_rolling_sort['recent_carry_to_fuml'] = player_rolling_sort['recent_ra'] / player_rolling_sort['recent_fuml']

# %% [markdown]
# ### Receiving stats

# %% [markdown]
# #### Career stats

# %%
#catch percent (catches/targets)
player_rolling_sort['career_catch_pct'] = player_rolling_sort['cusum_rec'] / player_rolling_sort['cusum_trg']

# %%
#yards per catch
player_rolling_sort['career_yds_per_rec'] = player_rolling_sort['cusum_recy'] / player_rolling_sort['cusum_rec']

# %%
#rec to td's
player_rolling_sort['career_rec_to_td'] = player_rolling_sort['cusum_rec'] / player_rolling_sort['cusum_tdrec']

# %% [markdown]
# #### Recent stats

# %%
#catch percent (catches/targets)
player_rolling_sort['recent_catch_pct'] = player_rolling_sort['recent_rec'] / player_rolling_sort['recent_trg']

# %%
#yards per catch
player_rolling_sort['recent_yds_per_rec'] = player_rolling_sort['recent_recy'] / player_rolling_sort['recent_rec']

# %%
#rec to td's
player_rolling_sort['recent_rec_to_td'] = player_rolling_sort['recent_rec'] / player_rolling_sort['recent_tdrec']

# %% [markdown]
# ### Return stats

# %% [markdown]
# #### Career stats

# %%
#average return yards
player_rolling_sort['career_avg_ret'] = player_rolling_sort['cusum_rety'] / player_rolling_sort['cusum_ret']

# %%
#returns to td's
player_rolling_sort['career_ret_to_td'] = player_rolling_sort['cusum_ret'] / player_rolling_sort['cusum_tdret']

# %% [markdown]
# #### Recent stats

# %%
#average return yards
player_rolling_sort['recent_avg_ret'] = player_rolling_sort['recent_rety'] / player_rolling_sort['recent_ret']

# %%
#returns to td's
player_rolling_sort['recent_ret_to_td'] = player_rolling_sort['recent_ret'] / player_rolling_sort['recent_tdret']

# %% [markdown]
# #### Age

# %%
#strip out the year from DOB
dob_year = player_rolling_sort['dob'].apply(lambda x: int(str(x[-4:])))

# %%
dob_year.head()
# Out:
# 74708    1993
# 74935    1993
# 75490    1993
# 75814    1993
# 76021    1993
# Name: dob, dtype: int64

# %%
#add age to dataframe
player_rolling_sort['age'] = player_rolling_sort['seas'].astype(int) - dob_year

# %%
player_rolling_sort['age'].head()
# Out:
# 74708    22
# 74935    22
# 75490    22
# 75814    22
# 76021    22
# Name: age, dtype: int64

# %% [markdown]
# ### Final checks

# %%
player_rolling_sort.columns
# Out:
# Index(['pk', 'gid', 'seas', 'wk', 'player', 'fname', 'lname', 'full_name',
#        'team', 'pos1', 'nflid', 'pa', 'pc', 'py', 'ints', 'tdp', 'ra', 'sra',
#        'ry', 'tdr', 'fuml', 'trg', 'rec', 'recy', 'tdrec', 'ret', 'rety',
#        'tdret', 'exp', 'height', 'weight', 'dob', 'dv', 'forty', 'bench',
#        'vertical', 'broad', 'shuttle', 'cone', 'arm', 'hand', 'cusum_pa',
#        'cusum_pc', 'cusum_py', 'cusum_ints', 'cusum_tdp', 'cusum_ra',
#        'cusum_sra', 'cusum_ry', 'cusum_tdr', 'cusum_fuml', 'cusum_trg',
#        'cusum_rec', 'cusum_recy', 'cusum_tdrec', 'cusum_ret', 'cusum_rety',
#        'cusum_tdret', 'recent_pa', 'recent_pc', 'recent_py', 'recent_ints',
#        'recent_tdp', 'recent_ra', 'recent_sra', 'recent_ry', 'recent_tdr',
#        'recent_fuml', 'recent_trg', 'recent_rec', 'recent_recy',
#        'recent_tdrec', 'recent_ret', 'recent_rety', 'recent_tdret',
#        'career_comp_pct', 'career_td_to_int', 'career_yds_per_comp',
#        'recent_comp_pct', 'recent_td_to_int', 'recent_yds_per_comp',
#        'career_ryds_per_carry', 'career_carry_to_td', 'career_carry_to_fuml',
#        'recent_ryds_per_carry', 'recent_carry_to_td', 'recent_carry_to_fuml',
#        'career_catch_pct', 'career_yds_per_rec', 'career_rec_to_td',
#        'recent_catch_pct', 'recent_yds_per_rec', 'recent_rec_to_td',
#        'career_avg_ret', 'career_ret_to_td', 'recent_avg_ret',
#        'recent_ret_to_td', 'age'],
#       dtype='object')

# %%
#percentage of players that played in more than xx games
game_thres = 10
sum(player_rolling_sort.groupby(by='player')['gid'].count() > game_thres) / len(player_rolling_sort.groupby(by='player')['gid'].count())
# Out:
# 0.5866666666666667

# %% [markdown]
# ## Game features

# %% [markdown]
# ### Read in data

# %%
game = pd.read_csv('https://raw.githubusercontent.com/jchristo12/fantasy_football/master/data/predictor/game.csv')

# %%
#change the data types to the correct format
game = game.astype({'v': 'category',
                   'h': 'category',
                   'day': 'category',
                   'cond': 'category',
                   'stad': 'category',
                   'wdir': 'category',
                   'surf': 'category'})

# %%
game.head()
# Out:
#    gid    v    h  day           cond                      stad   temp wdir  \
# 0    1   SF  ATL  SUN           Dome              Georgia Dome   79.0  NaN
# 1    2  JAC  CLE  SUN          Sunny  Cleveland Browns Stadium   78.0   NE
# 2    3  PHI  DAL  SUN          Sunny             Texas Stadium  109.0    S
# 3    4  NYJ   GB  SUN  Mostly Cloudy             Lambeau Field   77.0    E
# 4    5  IND   KC  SUN   Mostly Sunny         Arrowhead Stadium   90.0    E
#
#         surf  humd    ou  sprv  ptsv  ptsh
# 0  AstroTurf   NaN  42.5   7.0    28    36
# 1      Grass  63.0  38.0 -10.0    27     7
# 2  AstroTurf  19.0  40.0   6.0    41    14
# 3      Grass  66.0  36.0   2.5    20    16
# 4      Grass  50.0  44.0  -3.0    27    14

# %% [markdown]
# ### Feature creation

# %% [markdown]
# #### Underdog feature

# %%
#add underdog category
game['udog'] = pd.Series(np.where(game['sprv'] > 0, game['v'], game['h']))
game = game.astype({'udog': 'category'})

# %%
game.head()
# Out:
#    gid    v    h  day           cond                      stad   temp wdir  \
# 0    1   SF  ATL  SUN           Dome              Georgia Dome   79.0  NaN
# 1    2  JAC  CLE  SUN          Sunny  Cleveland Browns Stadium   78.0   NE
# 2    3  PHI  DAL  SUN          Sunny             Texas Stadium  109.0    S
# 3    4  NYJ   GB  SUN  Mostly Cloudy             Lambeau Field   77.0    E
# 4    5  IND   KC  SUN   Mostly Sunny         Arrowhead Stadium   90.0    E
#
#         surf  humd    ou  sprv  ptsv  ptsh udog
# 0  AstroTurf   NaN  42.5   7.0    28    36   SF
# 1      Grass  63.0  38.0 -10.0    27     7  CLE
# 2  AstroTurf  19.0  40.0   6.0    41    14  PHI
# 3      Grass  66.0  36.0   2.5    20    16  NYJ
# 4      Grass  50.0  44.0  -3.0    27    14   KC

# %%
#count how many times each team has been an underdog
tot_udog = game.groupby(by='udog')['sprv'].count().sort_values(ascending=False)
tot_udog
# Out:
# udog
# CLE    242
# DET    205
# OAK    203
# ARI    202
# WAS    198
# JAC    197
# BUF    196
# MIA    185
# SF     183
# CHI    180
# NYJ    179
# TB     177
# CIN    172
# HOU    169
# CAR    159
# KC     156
# TEN    155
# MIN    153
# NYG    152
# ATL    150
# STL    147
# SEA    143
# DAL    139
# SD     134
# BAL    127
# NO     121
# PHI    115
# GB     109
# IND    109
# DEN    107
# PIT     90
# NE      71
# LA      20
# LAC     12
# Name: sprv, dtype: int64

# %% [markdown]
# #### Dome vs. non-Dome

# %%
#game.groupby('cond').cond.count()

# %%
#dictionary of general conditions
general_cond = {'indoor_cond': ['Closed Roof', 'Covered Roof', 'Dome'], 
                'percip_cond': ['Flurries', 'Light Rain', 'Light Showers', 'Light Snow',
                                'Rain', 'Showers', 'Snow', 'Thuderstorms', 'Chance Rain'],
                'fair_cond': ['Clear', 'Sunny', 'Cloudy', 'Cold', 'Fair', 'Foggy', 'Hazy', 'Mostly Cloudy',
                              'Mostly Sunny', 'Overcast', 'Partly Cloudy', 'Partly CLoudy', 'Partly Sunny',
                              'Sunny', 'Windy']}

# %%
#indoor_cond =  ['Closed Roof', 'Covered Roof', 'Dome']

# %%
#map the keys to each value to be used in category creation
#general_cond_x = {old: new for new, old_all in general_cond.items() for old in old_all}

# %%
#create a general conditions feature

# %%
#pd.Categorical(game['cond'], categories=general_cond_x, ordered=False)

# %% [markdown]
# ### Combine data

# %%
#combine game and offensive player data
player_game = player_rolling_sort.merge(game, how='left', on='gid', suffixes=('_poff', '_game'))

# %%
player_game.head()
# Out:
#              pk   gid  seas wk   player  fname     lname       full_name team  \
# 0  3999&AA-0025  3999  2015  1  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 1  4010&AA-0025  4010  2015  2  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 2  4036&AA-0025  4036  2015  3  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 3  4052&AA-0025  4052  2015  4  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 4  4062&AA-0025  4062  2015  5  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
#
#   pos1  ...                stad  temp  wdir       surf  humd    ou  sprv  \
# 0   RB  ...    Qualcomm Stadium  84.0   WSW      Grass  47.0  46.0   3.0
# 1   RB  ...    TCF Bank Stadium  67.0   NaN  FieldTurf   NaN  43.5   2.0
# 2   RB  ...          Ford Field   NaN   NaN  FieldTurf   NaN  44.5  -3.0
# 3   RB  ...   CenturyLink Field  74.0     N  FieldTurf  41.0  43.0  10.0
# 4   RB  ...          Ford Field   NaN   NaN  FieldTurf   NaN  44.5  -3.0
#
#    ptsv  ptsh  udog
# 0    28    33   DET
# 1    16    26   DET
# 2    24    12   DET
# 3    10    13   DET
# 4    42    17   DET
#
# [5 rows x 112 columns]

# %% [markdown]
# ### Defensive Rankings features

# %%
#create a new categorical column of the defensive team
player_game['def_team'] = pd.Series(np.where(player_game['team'] == player_game['h'], player_game['v'], player_game['h']), dtype='category')

# %%
#sum the offensive stats given up by the defense by team, season, and week
team_seas_wk = player_game.groupby(['def_team', 'seas', 'wk'], as_index=True).sum().loc[:, 'pa':'tdret']
seas_wk_team = player_game.groupby(['seas', 'wk', 'def_team'], as_index=True).sum().loc[:, 'pa':'tdret']

# %% [markdown]
# NaN weeks represent each team's bye week

# %%
#remove the bye weeks
t_s_w_no_bye = team_seas_wk[team_seas_wk.notna().all(axis=1)]
s_w_t_no_bye = seas_wk_team[seas_wk_team.notna().all(axis=1)]

# %% [markdown]
# #### Calculate running totals for each

# %% [markdown]
# Need to lag by one week. Will calculate season running total and 4 game running total

# %%
test = t_s_w_no_bye.reset_index(level=['def_team', 'seas', 'wk'])

# %%
#reset index and then regroup by team and season
t_s_w_grouped = t_s_w_no_bye.reset_index(['def_team', 'seas', 'wk']).groupby(by=['def_team', 'seas'], as_index=True)

# %%
t_s_w_grouped.shift(1).rolling(window=4, min_periods=4).mean().loc[:, 'pa':'tdret'].add_prefix('mean_')
# Out:
#       mean_pa  mean_pc  mean_py  mean_ints  mean_tdp  mean_ra  mean_sra  \
# 0         NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 1         NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 2         NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 3         NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 4       31.00    20.25   230.75       0.25      1.25    32.75     16.75
# 5       30.25    20.00   222.25       0.00      1.25    30.25     14.75
# 6       30.50    20.00   218.00       0.00      0.75    34.25     17.25
# 7       26.25    17.75   184.50       0.00      1.00    35.25     20.00
# 8       24.50    16.25   171.25       0.25      1.00    34.50     18.75
# 9       28.75    17.25   205.75       0.75      1.00    36.00     20.50
# 10      28.50    17.75   225.75       1.00      1.50    34.75     19.75
# 11      33.25    21.75   241.50       1.25      1.25    32.50     17.00
# 12      34.25    22.75   257.75       1.00      1.25    35.25     18.25
# 13      30.25    20.50   216.00       0.75      1.50    39.50     20.50
# 14      27.00    17.75   203.25       0.50      1.50    42.50     22.00
# 15        NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 16        NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 17        NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 18        NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 19      27.25    19.00   231.00       0.75      2.00    33.25     15.25
# 20      30.50    18.75   258.50       1.25      1.50    29.00     13.75
# 21      28.25    16.00   210.25       1.50      0.75    29.00     14.00
# 22      29.25    16.00   199.75       1.50      0.75    27.00     12.25
# 23      30.00    16.00   209.50       1.25      1.00    29.25     13.25
# 24      34.50    19.75   230.50       1.50      1.50    29.75     13.50
# 25      40.75    25.75   284.25       1.25      2.00    27.00     12.50
# 26      43.75    28.25   300.25       1.50      2.25    29.50     14.50
# 27      44.25    29.25   314.00       1.25      2.25    28.00     13.75
# 28      36.75    23.75   241.75       0.50      2.00    28.75     13.75
# 29      33.00    19.50   208.75       1.00      1.75    33.00     15.75
# ...       ...      ...      ...        ...       ...      ...       ...
# 9062      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9063      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9064      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9065      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9066    33.00    21.75   241.25       1.00      1.25    22.50     10.25
# 9067    35.00    21.00   234.25       1.00      1.00    21.50     11.25
# 9068    35.00    21.50   239.50       1.00      1.75    24.25     11.75
# 9069    32.75    20.25   245.75       0.50      1.50    30.75     16.75
# 9070    34.75    19.50   246.75       1.00      1.75    30.00     16.25
# 9071    30.25    19.00   253.00       1.25      2.50    32.75     17.25
# 9072    34.25    22.00   282.25       1.25      2.00    30.25     17.25
# 9073    35.50    21.75   274.75       1.50      2.00    26.50     13.50
# 9074    29.75    18.50   226.00       1.00      2.00    30.00     15.50
# 9075    31.00    18.00   230.50       0.75      1.50    31.00     16.00
# 9076    31.00    14.75   181.50       0.75      1.00    33.75     18.00
# 9077      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9078      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9079      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9080      NaN      NaN      NaN        NaN       NaN      NaN       NaN
# 9081    34.75    23.50   240.00       0.75      1.75    23.00     12.00
# 9082    36.25    25.25   270.50       0.75      2.25    23.75     12.00
# 9083    37.25    25.50   294.00       0.25      2.00    22.25     12.00
# 9084    37.75    26.25   306.75       0.75      1.75    21.50     10.50
# 9085    40.00    26.25   303.50       1.00      2.00    19.50     10.25
# 9086    40.25    26.75   336.25       1.25      1.50    21.00     10.75
# 9087    37.50    25.25   320.00       1.75      1.50    23.25     11.00
# 9088    33.50    23.25   313.25       1.25      1.75    28.25     14.00
# 9089    33.75    23.50   302.25       1.25      1.25    30.50     13.75
# 9090    30.25    19.75   250.00       1.00      2.00    33.00     15.00
# 9091    28.50    18.00   212.25       0.75      1.75    31.75     14.75
#
#       mean_ry  mean_tdr  mean_fuml  mean_trg  mean_rec  mean_recy  mean_tdrec  \
# 0         NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 1         NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 2         NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 3         NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 4      154.75      1.50       1.25     30.75     20.25     230.75        1.25
# 5      125.00      1.50       1.00     30.25     20.00     222.25        1.25
# 6      145.50      2.25       0.50     30.50     20.00     218.00        0.75
# 7      151.25      2.75       0.25     26.25     17.75     184.50        1.00
# 8      141.00      2.50       0.00     24.50     16.25     171.25        1.00
# 9      156.00      2.00       0.25     28.25     17.25     205.75        1.00
# 10     152.50      1.50       0.50     27.75     17.75     225.75        1.50
# 11     136.25      1.25       0.75     32.50     21.75     241.50        1.25
# 12     150.50      1.75       1.00     33.50     22.75     257.75        1.25
# 13     182.50      2.00       0.75     30.00     20.50     216.00        1.50
# 14     196.50      2.25       0.50     26.75     17.75     203.25        1.50
# 15        NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 16        NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 17        NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 18        NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 19     143.50      0.75       0.50     26.25     19.00     231.00        2.00
# 20     136.50      0.50       0.50     29.25     18.75     258.50        1.50
# 21     145.00      0.50       0.50     27.00     16.00     210.25        0.75
# 22     128.50      0.50       0.25     28.00     16.00     199.75        0.75
# 23     140.75      0.50       0.00     28.50     16.00     209.50        1.00
# 24     123.25      1.00       0.00     32.50     19.75     230.50        1.50
# 25     108.00      0.75       0.25     39.00     25.75     284.25        2.00
# 26     113.50      1.00       0.50     42.25     28.25     300.25        2.25
# 27      99.50      1.00       0.50     42.75     29.25     314.00        2.25
# 28     113.50      0.50       0.50     36.25     23.75     241.75        2.00
# 29     136.00      0.50       0.50     31.75     19.50     208.75        1.75
# ...       ...       ...        ...       ...       ...        ...         ...
# 9062      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9063      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9064      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9065      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9066    88.75      0.50       0.75     32.25     21.75     241.25        1.25
# 9067    95.50      1.00       0.50     34.50     21.00     234.25        1.00
# 9068   103.00      0.75       0.25     34.25     21.50     239.50        1.75
# 9069   137.25      1.25       0.25     32.25     20.25     245.75        1.50
# 9070   132.25      1.00       0.25     33.75     19.50     246.75        1.75
# 9071   136.50      0.75       0.25     29.25     19.00     253.00        2.50
# 9072   144.75      1.00       0.25     33.00     22.00     282.25        2.00
# 9073   123.50      0.50       0.00     34.00     21.75     274.75        2.00
# 9074   132.00      1.00       0.00     29.25     18.50     226.00        2.00
# 9075   150.00      1.00       0.00     30.50     18.00     230.50        1.50
# 9076   145.25      0.75       0.25     30.50     14.75     181.50        1.00
# 9077      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9078      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9079      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9080      NaN       NaN        NaN       NaN       NaN        NaN         NaN
# 9081    92.50      1.25       0.75     34.75     23.50     240.00        1.75
# 9082    95.75      1.00       1.00     35.75     25.25     270.50        2.25
# 9083    88.00      1.00       1.50     36.75     25.50     294.00        2.00
# 9084    72.25      1.00       1.25     37.00     26.25     306.75        1.75
# 9085    86.25      0.50       1.00     39.00     26.25     303.50        2.00
# 9086    91.75      0.50       1.00     39.75     26.75     336.25        1.50
# 9087   108.25      0.25       0.75     37.00     25.25     320.00        1.50
# 9088   135.50      0.75       0.75     33.00     23.25     313.25        1.75
# 9089   129.50      0.75       0.75     33.25     23.50     302.25        1.25
# 9090   160.50      1.00       0.25     29.50     19.75     250.00        2.00
# 9091   168.75      1.00       0.25     27.50     18.00     212.25        1.75
#
#       mean_ret  mean_rety  mean_tdret
# 0          NaN        NaN         NaN
# 1          NaN        NaN         NaN
# 2          NaN        NaN         NaN
# 3          NaN        NaN         NaN
# 4         4.50      64.00        0.25
# 5         4.75      81.75        0.25
# 6         4.25      61.00        0.00
# 7         5.50      78.00        0.25
# 8         6.00      90.00        0.25
# 9         5.25      75.00        0.25
# 10        5.00      66.00        0.25
# 11        5.50      57.50        0.00
# 12        5.75      49.50        0.00
# 13        5.25      34.00        0.00
# 14        5.75      40.50        0.00
# 15         NaN        NaN         NaN
# 16         NaN        NaN         NaN
# 17         NaN        NaN         NaN
# 18         NaN        NaN         NaN
# 19        3.75      63.50        0.00
# 20        4.50      45.50        0.00
# 21        5.50      56.75        0.00
# 22        6.00      84.75        0.25
# 23        6.00      84.75        0.25
# 24        7.25     113.50        0.25
# 25        8.25     125.75        0.25
# 26        8.75     117.50        0.00
# 27        8.75     118.25        0.00
# 28        7.25      80.25        0.00
# 29        7.50      83.25        0.00
# ...        ...        ...         ...
# 9062       NaN        NaN         NaN
# 9063       NaN        NaN         NaN
# 9064       NaN        NaN         NaN
# 9065       NaN        NaN         NaN
# 9066      4.25      45.50        0.00
# 9067      4.50      55.25        0.00
# 9068      4.25      41.75        0.00
# 9069      4.00      40.25        0.00
# 9070      4.75      49.00        0.00
# 9071      4.00      39.25        0.00
# 9072      4.75      55.25        0.00
# 9073      5.50      60.75        0.00
# 9074      4.75      63.25        0.25
# 9075      5.75      75.50        0.25
# 9076      5.50      63.75        0.25
# 9077       NaN        NaN         NaN
# 9078       NaN        NaN         NaN
# 9079       NaN        NaN         NaN
# 9080       NaN        NaN         NaN
# 9081      4.00      29.50        0.00
# 9082      4.00      27.75        0.00
# 9083      4.75      32.25        0.00
# 9084      4.50      30.00        0.00
# 9085      4.75      31.00        0.00
# 9086      4.50      23.50        0.00
# 9087      4.00      22.75        0.00
# 9088      3.25      11.50        0.00
# 9089      4.00      20.75        0.00
# 9090      4.75      31.50        0.00
# 9091      4.75      50.25        0.25
#
# [9092 rows x 17 columns]

# %%
t_s_w_grouped.shift(1).rolling(window=4, min_periods=1).mean().head(8)
# Out:
#          wk         pa         pc          py      ints       tdp     ra  \
# 0       NaN        NaN        NaN         NaN       NaN       NaN    NaN
# 1  1.000000  25.000000  17.000000  172.000000  1.000000  0.000000  41.00
# 2  1.500000  29.500000  20.500000  207.500000  0.500000  1.500000  31.50
# 3  2.333333  30.333333  19.666667  234.333333  0.333333  1.333333  33.00
# 4  3.000000  31.000000  20.250000  230.750000  0.250000  1.250000  32.75
# 5  4.250000  30.250000  20.000000  222.250000  0.000000  1.250000  30.25
# 6  5.500000  30.500000  20.000000  218.000000  0.000000  0.750000  34.25
# 7  6.500000  26.250000  17.750000  184.500000  0.000000  1.000000  35.25
#
#          sra      ry       tdr      fuml    trg        rec        recy  \
# 0        NaN     NaN       NaN       NaN    NaN        NaN         NaN
# 1  21.000000  223.00  3.000000  1.000000  24.00  17.000000  172.000000
# 2  16.500000  156.50  1.500000  1.500000  29.00  20.500000  207.500000
# 3  16.333333  163.00  1.333333  1.333333  30.00  19.666667  234.333333
# 4  16.750000  154.75  1.500000  1.250000  30.75  20.250000  230.750000
# 5  14.750000  125.00  1.500000  1.000000  30.25  20.000000  222.250000
# 6  17.250000  145.50  2.250000  0.500000  30.50  20.000000  218.000000
# 7  20.000000  151.25  2.750000  0.250000  26.25  17.750000  184.500000
#
#       tdrec   ret        rety     tdret
# 0       NaN   NaN         NaN       NaN
# 1  0.000000  7.00   73.000000  0.000000
# 2  1.500000  7.50  117.500000  0.500000
# 3  1.333333  5.00   78.333333  0.333333
# 4  1.250000  4.50   64.000000  0.250000
# 5  1.250000  4.75   81.750000  0.250000
# 6  0.750000  4.25   61.000000  0.000000
# 7  1.000000  5.50   78.000000  0.250000

# %% [markdown]
# <br>The below code will calculate the ranks for each of the columns<br>
# Have to separate out stats that should be ranked ascending (more is worse) and decending (more is better)

# %%
#reset the index and regroup so that the ranks are calculated by subgroups
#s_w_t_grouped = s_w_t_no_bye.reset_index(level=['seas', 'wk', 'def_team']).groupby(['seas', 'wk'], as_index=False)

# %%
#s_w_t_grouped['py'].rank(method='dense', ascending=True).add_prefix('rank_')

# %% [markdown]
# # Feature and Response variables

# %% [markdown]
# ### Initial setup

# %%
#read in the offensive player response variables
ft_pts = pd.read_csv('https://raw.githubusercontent.com/jchristo12/fantasy_football/master/data/response/offense_final.csv',
                     header=0)

# %%
ft_pts.head()
# Out:
#           pk  gid  seas  wk   player pos1   py  ints  tdp  ry  tdr  recy  \
# 0  1&KW-1500    1  2000   1  KW-1500   WR    0     0    0   0    0     0
# 1  1&CG-0400    1  2000   1  CG-0400   RB    0     0    0  62    0    45
# 2  1&JG-0600    1  2000   1  JG-0600   QB  252     1    3  22    0     0
# 3  1&JR-2000    1  2000   1  JR-2000   WR    0     0    0  -2    0    59
# 4  1&TO-0200    1  2000   1  TO-0200   WR    0     0    0   0    0    72
#
#    tdrec  rety  tdret  fuml  conv  tot_sack  f_pts
# 0      0    56      0     0     0       0.0   1.60
# 1      0     0      0     0     0       0.0  10.70
# 2      0     0      0     0     0       1.0  22.03
# 3      0     0      0     0     0       0.0   5.70
# 4      1     0      0     0     0       0.0  13.20

# %%
#trim the columns
response = ft_pts.loc[:, ['pk', 'f_pts']]
response.head()
# Out:
#           pk  f_pts
# 0  1&KW-1500   1.60
# 1  1&CG-0400  10.70
# 2  1&JG-0600  22.03
# 3  1&JR-2000   5.70
# 4  1&TO-0200  13.20

# %% [markdown]
# ### Merge response and feature df's

# %%
full_df = player_game.merge(response, on='pk', how='left')
full_df.head()
# Out:
#              pk   gid  seas wk   player  fname     lname       full_name team  \
# 0  3999&AA-0025  3999  2015  1  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 1  4010&AA-0025  4010  2015  2  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 2  4036&AA-0025  4036  2015  3  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 3  4052&AA-0025  4052  2015  4  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
# 4  4062&AA-0025  4062  2015  5  AA-0025  Ameer  Abdullah  Ameer Abdullah  DET
#
#   pos1    ...      temp  wdir       surf  humd    ou  sprv  ptsv  ptsh  udog  \
# 0   RB    ...      84.0   WSW      Grass  47.0  46.0   3.0    28    33   DET
# 1   RB    ...      67.0   NaN  FieldTurf   NaN  43.5   2.0    16    26   DET
# 2   RB    ...       NaN   NaN  FieldTurf   NaN  44.5  -3.0    24    12   DET
# 3   RB    ...      74.0     N  FieldTurf  41.0  43.0  10.0    10    13   DET
# 4   RB    ...       NaN   NaN  FieldTurf   NaN  44.5  -3.0    42    17   DET
#
#        f_pts
# 0  18.400000
# 1   4.200000
# 2  10.200000
# 3   5.942857
# 4   1.671429
#
# [5 rows x 113 columns]

# %%
print(full_df.shape)
full_df.columns
# Out:
# (94759, 113)
# Index(['pk', 'gid', 'seas', 'wk', 'player', 'fname', 'lname', 'full_name',
#        'team', 'pos1',
#        ...
#        'temp', 'wdir', 'surf', 'humd', 'ou', 'sprv', 'ptsv', 'ptsh', 'udog',
#        'f_pts'],
#       dtype='object', length=113)

# %% [markdown]
# Everything looks good!

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#remove observations that don't have NaN for fantasy points
df_eda = full_df[full_df['f_pts'].notna()]

# %%
#store positions of interest
pos_of_interest = ['QB', 'RB', 'WR', 'TE']

# %%
#filter out positions that aren't primary offense positions
df_eda = full_df[full_df['pos1'].isin(pos_of_interest)]
#remove unused categories
df_eda['pos1'] = df_eda['pos1'].cat.remove_unused_categories()
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
sb.catplot(x='seas', y='f_pts', hue='pos1', hue_order=['TE'], kind='box', data=df_eda)

# %%
#list out all of the columns
for i in df_eda.columns:
    print(i)
# Out:
# pk
# gid
# seas
# wk
# player
# fname
# lname
# full_name
# team
# pos1
# nflid
# pa
# pc
# py
# ints
# tdp
# ra
# sra
# ry
# tdr
# fuml
# trg
# rec
# recy
# tdrec
# ret
# rety
# tdret
# exp
# height
# weight
# dob
# dv
# forty
# bench
# vertical
# broad
# shuttle
# cone
# arm
# hand
# cusum_pa
# cusum_pc
# cusum_py
# cusum_ints
# cusum_tdp
# cusum_ra
# cusum_sra
# cusum_ry
# cusum_tdr
# cusum_fuml
# cusum_trg
# cusum_rec
# cusum_recy
# cusum_tdrec
# cusum_ret
# cusum_rety
# cusum_tdret
# recent_pa
# recent_pc
# recent_py
# recent_ints
# recent_tdp
# recent_ra
# recent_sra
# recent_ry
# recent_tdr
# recent_fuml
# recent_trg
# recent_rec
# recent_recy
# recent_tdrec
# recent_ret
# recent_rety
# recent_tdret
# career_comp_pct
# career_td_to_int
# career_yds_per_comp
# recent_comp_pct
# recent_td_to_int
# recent_yds_per_comp
# career_ryds_per_carry
# career_carry_to_td
# career_carry_to_fuml
# recent_ryds_per_carry
# recent_carry_to_td
# recent_carry_to_fuml
# career_catch_pct
# career_yds_per_rec
# career_rec_to_td
# recent_catch_pct
# recent_yds_per_rec
# recent_rec_to_td
# career_avg_ret
# career_ret_to_td
# recent_avg_ret
# recent_ret_to_td
# age
# v
# h
# day
# cond
# stad
# temp
# wdir
# surf
# humd
# ou
# sprv
# ptsv
# ptsh
# udog
# f_pts

# %% [markdown]
# #### Explore the underdog feature

# %%
#create new column of binary underdog
df_eda['udog_bin'] = df_eda['team'].eq(df_eda['udog'])
#convert to category
df_eda['udog_bin'] = df_eda['udog_bin'].astype('category')
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Joe\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
sb.catplot(x='pos1', y='f_pts', hue='udog_bin', kind='box', data=df_eda)

# %%
df_eda.groupby(['pos1', 'udog_bin'], as_index=True).agg({'f_pts': ['min', 'max', 'mean', 'median']})
# Out:
#                   f_pts
#                     min    max       mean     median
# pos1 udog_bin
# QB   False    -7.440000  48.82  13.065708  13.070000
#      True     -7.990000  44.99  10.789780  10.320000
# RB   False    -2.800000  55.40   6.609011   3.700000
#      True     -2.800000  51.20   5.627840   3.200000
# TE   False    -2.200000  33.40   3.753956   2.000000
#      True     -3.300000  32.00   3.203514   1.600000
# WR   False    -4.342857  41.40   5.865394   3.771429
#      True     -3.500000  47.10   5.165432   3.300000

# %% [markdown]
# #### Analyze the cumulative stat features

# %%
#remove rows where it is NA due to the lag
df_eda_roll = df_eda[~df_eda.loc[:, 'cusum_pa':'recent_tdret'].isna().any(axis=1)]

# %%
#career passing versus next week's fantasy points
df_eda_roll.loc[(df_eda_roll['pos1']=='QB') & (df_eda_roll['cusum_pa'] > 100), ['f_pts', 'cusum_py']].corr(method='pearson')
# Out:
#              f_pts  cusum_py
# f_pts     1.000000  0.230815
# cusum_py  0.230815  1.000000

# %%
sb.scatterplot(x='cusum_py', y='f_pts',
               data=df_eda_roll.loc[(df_eda_roll['pos1']=='QB') & (df_eda_roll['cusum_pa'] > 100), :])

# %% [markdown]
# ### Game features

# %%
df_eda_roll.groupby(['pos1', 'day']).agg({'f_pts': ['median', 'count']})
# Out:
#                             f_pts
#                            median count
# pos1 day cond
# QB   FRI Cloudy          7.195000     6
#          Dome           24.725000     2
#      MN  Chance Rain     7.610000    19
#          Clear          13.145000   228
#          Closed Roof    13.570000    45
#          Cloudy         12.515000   120
#          Dome           13.115000   126
#          Fair            8.635000     8
#          Flurries       15.450000     2
#          Foggy          15.210000     2
#          Hazy           17.315000     6
#          Light Rain      7.090000    11
#          Light Showers   6.310000     3
#          Mostly Cloudy  11.440000    25
#          Partly Cloudy  12.225000    72
#          Rain           12.010000    27
#          Snow            6.290000     9
#          Sunny          12.315000    30
#      SAT Chance Rain     7.760000     3
#          Clear          13.765000    26
#          Closed Roof    11.970000     7
#          Cloudy         10.630000    34
#          Dome           15.645000    20
#          Fair           16.595000     2
#          Light Rain     10.015000     2
#          Mostly Cloudy  16.020000     2
#          Mostly Sunny   13.435000     2
#          Partly Cloudy  10.235000    24
#          Rain            3.890000     6
#          Sunny          10.615000    26
# ...                           ...   ...
# WR   SUN Foggy           3.142857    26
#          Hazy            3.700000    87
#          Light Rain      3.100000   299
#          Light Snow      3.600000    86
#          Mostly Cloudy   3.600000  1226
#          Mostly Sunny    3.428571   838
#          Overcast        3.800000    19
#          Partly CLoudy   2.371429     7
#          Partly Cloudy   3.600000  2888
#          Partly Sunny    3.500000   550
#          Rain            3.000000   955
#          Showers         7.400000     9
#          Snow            2.200000   190
#          Sunny           3.500000  7281
#          Thunderstorms   3.614286    10
#      THU Chance Rain     3.500000    47
#          Clear           3.300000   408
#          Closed Roof     3.800000   191
#          Cloudy          3.100000   224
#          Cold            2.900000     6
#          Dome            3.750000   330
#          Fair            4.200000    46
#          Light Rain      4.050000    16
#          Mostly Cloudy   5.307143    34
#          Mostly Sunny    1.992857    28
#          Partly Cloudy   3.800000   133
#          Rain            3.900000    57
#          Sunny           2.950000    30
#      TN  Partly Cloudy   1.600000     9
#      WED Fair            5.800000     7
#
# [340 rows x 2 columns]
